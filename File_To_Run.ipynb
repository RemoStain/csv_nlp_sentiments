# %%
from nlp.SocialCleaner import CsvCommentCleaner as CCC
import nlp.sentence_sentiment_analyzer as ssa
from nlp.safe_input import safe_input

# %%
cleaner = CCC()
comments_df = cleaner.run()
print(comments_df.head())
cleaner.save(comments_df)
# Out:
#    Content type                                        Content
# 12      Comment                                 Loooks great .
# 14      Comment                                    Where at??)
# 17      Comment  I still want that big clock on the wall lol 😊
# 63      Comment                Hello Do you need an employee ?
# 67      Comment                                           Nice
# Saved to: data.csv

# %%
ssa.main(0)
# Out:
# Filename: data.csv
# Column to check: Content
# Max number of lines (0 = all): 0
# Output to console? Y/n (default: False):
# Compute average only? Y/n (default: False):
# Average compound sentiment over 1940 sentences: 0.2996477319587635
# Sentences saved to sentiment_output.csv
